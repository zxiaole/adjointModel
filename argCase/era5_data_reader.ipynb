# %%
import cfgrib
import xarray as xr
# https://pypi.org/project/cfgrib/
# Automatic filtering
ds = cfgrib.open_datasets('ECMWF-20170101.grb')
# Out:
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# Ignoring index file 'ECMWF-20170101.grb.923a8.idx' incompatible with GRIB file
# ...

# %%
ds[3]
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 3, step: 12, latitude: 9, longitude: 10)
# Coordinates:
#     number      int64 0
#   * time        (time) datetime64[ns] 2016-12-31T18:00:00 ... 2017-01-01T18:0...
#   * step        (step) timedelta64[ns] 01:00:00 02:00:00 ... 11:00:00 12:00:00
#     surface     float64 0.0
#   * latitude    (latitude) float64 41.25 41.0 40.75 40.5 ... 39.75 39.5 39.25
#   * longitude   (longitude) float64 115.2 115.5 115.8 ... 117.0 117.2 117.5
#     valid_time  (time, step) datetime64[ns] 2016-12-31T19:00:00 ... 2017-01-0...
# Data variables:
#     lsp         (time, step, latitude, longitude) float32 ...
#     cp          (time, step, latitude, longitude) float32 ...
#     sshf        (time, step, latitude, longitude) float32 ...
#     ssrd        (time, step, latitude, longitude) float32 ...
#     ewss        (time, step, latitude, longitude) float32 ...
#     nsss        (time, step, latitude, longitude) float32 ...
# ...
